# %% [markdown]
# # Import packages and load data

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import ParameterGrid, cross_val_score
from sklearn.model_selection import train_test_split
from sklearn import model_selection
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV
from matplotlib import rc
xscaler = MinMaxScaler()

# %%
file_path = '../../input_data/pspeo_master.xlsx'
model_output = 'tri'
# import data frame for pre-processing
df = pd.read_excel(file_path)
df
# Out:
#       sample solv_ratio           add_type  swell_ratio  gisaxs_domain  \
# 0     I_A_AC      80/20  Chloronaphthalene         1.00      31.302630
# 1     I_A025      80/20  Chloronaphthalene         1.25      33.805848
# 2     I_A050      80/20  Chloronaphthalene         1.50      34.176062
# 3     I_A075      80/20  Chloronaphthalene         1.75      34.383751
# 4    I_A_100      80/20  Chloronaphthalene         2.00      31.674148
# ..       ...        ...                ...          ...            ...
# 197       Z7      80/20  Methylnaphthalene         2.50      35.569033
# 198       Z8      80/20  Methylnaphthalene         2.75      35.133195
# 199       Z9      80/20  Methylnaphthalene         3.00      34.889468
# 200      Z10      80/20  Methylnaphthalene         3.25      36.194647
# 201      Z11      80/20  Methylnaphthalene         3.50      34.487409
#
#      gisaxs_fwhm  afm_domain  afm_grain  tri
# 0       0.003697   33.737303     0.0048    0
# 1       0.003136   35.151690     0.0047    1
# 2       0.002970   35.397797     0.0534    1
# 3       0.003451   34.603726     0.0425    1
# 4       0.005122   33.786210     0.0244    1
# ..           ...         ...        ...  ...
# 197     0.003222   37.120415     0.1093    2
# 198     0.002910   36.469102     0.0907    2
# 199     0.002755   33.289887     0.1990    2
# 200     0.002669   37.443701     0.0807    2
# 201     0.003243   35.813966     0.0394    2
#
# [202 rows x 9 columns]

# %% [markdown]
# # Grid-Search

# %%
# Assign input variables and target variable, eliminating static valuesp
inputs = df.loc[:, ['solv_ratio', 'swell_ratio', 'add_type']]
target = df['tri']

# Define mapping for solv_ratio
type_mapping = {100: 1.0, '90/10': 0.9, '80/20': 0.8, '70/30': 0.7, '60/40': 0.6, '50/50': 0.5}
inputs['solv_ratio'] = inputs['solv_ratio'].replace(type_mapping)

# Encode categorical input 'add_type'
le_addType = LabelEncoder()
inputs['add_type'] = le_addType.fit_transform(inputs['add_type'])

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(inputs, target, test_size=0.2, random_state=10)

# Scale the x data for better fitting
xscaler.fit(X_train)
X_train = xscaler.transform(X_train)
X_test = xscaler.transform(X_test)

# %% [markdown]
# # Data pre-processing

# %%
# %%time

# Define parameter grid
param_grid = {
    'n_estimators': [10, 25, 50, 75, 100],
    'criterion': ["gini", "entropy"],  # valid for classifiers
    'max_depth': [None, 5, 10, 20, 30],
    'min_samples_split': [2, 5, 10, 20],
    'max_leaf_nodes': [None, 10, 20, 30, 50],
    'max_features': ['sqrt', 'log2', 1.0],  # 1.0 = use all features
    'bootstrap': [True, False]
}

# Set seed
RANDOM_SEED = 42
CV_FOLDS = 5

# Variables to store the best results
best_model = None
best_params = None
best_avg_score = float('-inf')

# Loop over all combinations
for params in ParameterGrid(param_grid):
    model = RandomForestClassifier(**params, random_state=RANDOM_SEED, n_jobs=-1)
    
    # Cross-validated accuracy on training set
    cv_scores = cross_val_score(model, X_train, y_train, cv=CV_FOLDS, scoring='accuracy', n_jobs=-1)
    cv_accuracy = np.mean(cv_scores)
    
    # Fit model to full training set
    model.fit(X_train, y_train)
    
    # Accuracy on test set
    test_accuracy = model.score(X_test, y_test)
    
    # Average accuracy: cross-val on train + test
    # avg_score = (cv_accuracy + test_accuracy) / 2

    if cv_accuracy > best_avg_score:
        best_avg_score = cv_accuracy
        best_model = model
        best_params = params
        best_cv_accuracy = cv_accuracy
        best_test_accuracy = test_accuracy

# Output the results
print("Best Average Accuracy (CV Train + Test):", best_avg_score)
print("CV Train Accuracy:", best_cv_accuracy)
print("Test Accuracy:", best_test_accuracy)
print("Best Parameters:", best_params)
# Out:
# Best Average Accuracy (CV Train + Test): 0.9626893939393939
# CV Train Accuracy: 0.9626893939393939
# Test Accuracy: 1.0
# Best Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_split': 2, 'n_estimators': 50}
# CPU times: user 5min 57s, sys: 1min 7s, total: 7min 4s
# Wall time: 11min 33s

# %%
best = RandomForestClassifier(**best_params, random_state=42, n_jobs=-1)
best.fit(X_train, y_train)
# test_r2 = model.score(X_test, y_test)  # or use r2_score(y_test, model.predict(X_test))
# Out:
# RandomForestClassifier(max_leaf_nodes=10, n_estimators=50, n_jobs=-1,
#                        random_state=42)

# %%
train_r2 = best.score(X_train, y_train)
test_r2 = best.score(X_test, y_test)

print(f'Training r2: {train_r2}')
print(f'Testing r2: {test_r2}')

# Create an array for x values
x_len = len(y_test)
actual_x = np.arange(1, x_len+1)

# Define the output path for figures
output_path = f'../final_figs/{model_output}/'
# Out:
# Training r2: 1.0
# Testing r2: 1.0

# %%
from joblib import dump, load

dump(best, f'{model_output}_cv.joblib')
# Out:
# ['tri_cv.joblib']

# %%
rfr_train = best.predict(X_train)
rfr_test = best.predict(X_test)

# %%
from sklearn.metrics import f1_score

# Make predictions using the best model
y_pred_train = best.predict(X_train)
y_pred_test = best.predict(X_test)

# Calculate the F1 score
f1_train = f1_score(y_train, y_pred_train)
f1_test = f1_score(y_test, y_pred_test)

print("Training F1 Score:", f1_train)
print("Testing F1 Score:", f1_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 8
#       5 y_pred_test = best.predict(X_test)
#       7 # Calculate the F1 score
# ----> 8 f1_train = f1_score(y_train, y_pred_train)
#       9 f1_test = f1_score(y_test, y_pred_test)
#      11 print("Training F1 Score:", f1_train)
#
# File ~/anaconda3/envs/cnn/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1146, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1011 def f1_score(
#    1012     y_true,
#    1013     y_pred,
#    (...)
#    1019     zero_division="warn",
#    1020 ):
#    1021     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1022
#    1023     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1144     array([0.66666667, 1.        , 0.66666667])
#    1145     """
# -> 1146     return fbeta_score(
#    1147         y_true,
#    1148         y_pred,
#    1149         beta=1,
#    1150         labels=labels,
#    1151         pos_label=pos_label,
#    1152         average=average,
#    1153         sample_weight=sample_weight,
#    1154         zero_division=zero_division,
#    1155     )
#
# File ~/anaconda3/envs/cnn/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1287, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1158 def fbeta_score(
#    1159     y_true,
#    1160     y_pred,
#    (...)
#    1167     zero_division="warn",
#    1168 ):
#    1169     """Compute the F-beta score.
#    1170
#    1171     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1284     array([0.71..., 0.        , 0.        ])
#    1285     """
# -> 1287     _, _, f, _ = precision_recall_fscore_support(
#    1288         y_true,
#    1289         y_pred,
#    1290         beta=beta,
#    1291         labels=labels,
#    1292         pos_label=pos_label,
#    1293         average=average,
#    1294         warn_for=("f-score",),
#    1295         sample_weight=sample_weight,
#    1296         zero_division=zero_division,
#    1297     )
#    1298     return f
#
# File ~/anaconda3/envs/cnn/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1573, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1571 if beta < 0:
#    1572     raise ValueError("beta should be >=0 in the F-beta score")
# -> 1573 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1575 # Calculate tp_sum, pred_sum, true_sum ###
#    1576 samplewise = average == "samples"
#
# File ~/anaconda3/envs/cnn/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1391, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1389         if y_type == "multiclass":
#    1390             average_options.remove("samples")
# -> 1391         raise ValueError(
#    1392             "Target is %s but average='binary'. Please "
#    1393             "choose another average setting, one of %r." % (y_type, average_options)
#    1394         )
#    1395 elif pos_label not in (None, 1):
#    1396     warnings.warn(
#    1397         "Note that pos_label (set to %r) is ignored when "
#    1398         "average != 'binary' (got %r). You may use "
#    (...)
#    1401         UserWarning,
#    1402     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
